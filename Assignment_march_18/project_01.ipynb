# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("liquor.csv")

# %%
df.head(20)
# Out:
#           date convenience_store  store                       name  \
# 0   2015-02-19               NaN   2190  Central City Liquor, Inc.
# 1   2015-02-09               NaN   2190  Central City Liquor, Inc.
# 2   2014-10-30               NaN   2190   Central City Liquor Inc.
# 3   2014-02-27               NaN   2190   Central City Liquor Inc.
# 4   2014-02-25               NaN   2190   Central City Liquor Inc.
# 5   2014-06-16               NaN   2190   Central City Liquor Inc.
# 6   2014-01-30               NaN   2190   Central City Liquor Inc.
# 7   2014-11-03               NaN   2190   Central City Liquor Inc.
# 8   2015-01-28               NaN   2200           Sac Liquor Store
# 9   2014-03-19               NaN   2200           Sac Liquor Store
# 10  2014-08-20               NaN   2200           Sac Liquor Store
# 11  2014-12-03               NaN   2200           Sac Liquor Store
# 12  2014-02-26               NaN   2200           Sac Liquor Store
# ...

# %%
this = "Anchor Distilling (PREISS IMPORTS)"

# %%
df["Anchor Distilling (PREISS IMPORTS)"] = df["vendor"].str.find(this)

# %%
df.head()
# Out:
#          date convenience_store  store                       name  \
# 0  2015-02-19               NaN   2190  Central City Liquor, Inc.
# 1  2015-02-09               NaN   2190  Central City Liquor, Inc.
# 2  2014-10-30               NaN   2190   Central City Liquor Inc.
# 3  2014-02-27               NaN   2190   Central City Liquor Inc.
# 4  2014-02-25               NaN   2190   Central City Liquor Inc.
#
#         address        city zipcode  \
# 0  1460 2ND AVE  DES MOINES   50314
# 1  1460 2ND AVE  DES MOINES   50314
# 2  1460 2ND AVE  DES MOINES   50314
# 3  1460 2ND AVE  DES MOINES   50314
# 4  1460 2ND AVE  DES MOINES   50314
#
#                                       store_location  county_number county  \
# 0  1460 2ND AVE\nDES MOINES 50314\n(41.6055703350...             77   Polk
# 1  1460 2ND AVE\nDES MOINES 50314\n(41.6055703350...             77   Polk
# 2  1460 2ND AVE\nDES MOINES 50314\n(41.6055703350...             77   Polk
# ...

# %%
x = df.pop("Anchor Distilling (PREISS IMPORTS)")

# %%
x = x.replace(to_replace = -1, value = 0)

# %%
x = x.replace(to_replace = 0, value = 1)

# %%
x
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 14995    1
# 14996    1
# 14997    1
# 14998    1
# 14999    1
# Name: Anchor Distilling (PREISS IMPORTS), Length: 15000, dtype: int64
